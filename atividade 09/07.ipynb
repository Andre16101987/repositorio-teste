# %%
import numpy as np
import pandas as pd

# %%
df_base = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep = ';', encoding = 'latin1')
df_base
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 36213   159    5  2025  2025m05    35     4  Cachoeiras de Macacu  3300803
# 36214   165    5  2025  2025m05    33     5           Mangaratiba  3302601
# 36215   166    5  2025  2025m05    33     5        Angra dos Reis  3300100
# 36216   167    5  2025  2025m05    43     5                Paraty  3303807
# 36217   168    5  2025  2025m05    28     5             Rio Claro  3304409
#
# ...

# %%
df_rj = df_base[['roubo_veiculo','furto_veiculos','cisp']]
df_rj
# Out:
#        roubo_veiculo  furto_veiculos  cisp
# 0                  5              12     1
# 1                  9               9     4
# 2                 11              28     5
# 3                 27              17     6
# 4                 23              12     7
# ...              ...             ...   ...
# 36213              0               2   159
# 36214              0               2   165
# 36215              0               4   166
# 36216              0               3   167
# 36217              0               1   168
#
# [36218 rows x 3 columns]

# %%
df_del= df_base.groupby('Rio de Janeiro')['roubo_veiculo','furto_veiculos'].sum().reset_index()
df_del
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_del= df_base.groupby('Rio de Janeiro')['roubo_veiculo','furto_veiculos'].sum().reset_index()
#       2 df_del
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...
